# %%
# !pip install scikit-learn==1.1.3
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 30.5/30.5 MB 52.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.2.2
#     Uninstalling scikit-learn-1.2.2:
#       Successfully uninstalled scikit-learn-1.2.2
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import load_boston

# %%
boston = load_boston()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function load_boston is deprecated; `load_boston` is deprecated in 1.0 and will be removed in 1.2.
#
#     The Boston housing prices dataset has an ethical problem. You can refer to
#     the documentation of this function for further details.
#
#     The scikit-learn maintainers therefore strongly discourage the use of this
#     dataset unless the purpose of the code is to study and educate about
#     ethical issues in data science and machine learning.
#
#     In this special case, you can fetch the dataset from the original
#     source::
#
#         import pandas as pd
#         import numpy as np
#
#         data_url = "http://lib.stat.cmu.edu/datasets/boston"
#         raw_df = pd.read_csv(data_url, sep="\s+", skiprows=22, header=None)
#         data = np.hstack([raw_df.values[::2, :], raw_df.values[1::2, :2]])
#         target = raw_df.values[1::2, 2]
#
# ...

# %%
df = pd.DataFrame(boston.data, columns = boston.feature_names)

# %%
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT
# 0     15.3  396.90   4.98
# 1     17.8  396.90   9.14
# 2     17.8  392.83   4.03
# 3     18.7  394.63   2.94
# 4     18.7  396.90   5.33

# %%
df.columns
# Out:
# Index(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
#        'PTRATIO', 'B', 'LSTAT'],
#       dtype='object')

# %%
df['MEDV'] = boston.target

# %%
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %%
df.columns
# Out:
# Index(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
#        'PTRATIO', 'B', 'LSTAT', 'MEDV'],
#       dtype='object')

# %% [markdown]
# **Dataset Description**
#
# The 13 input variables, also known as features, are as follows:
#
#
# CRIM: Per capita crime rate by town.
#
# ZN: Proportion of residential land zoned for lots over 25,000 square feet.
#
# INDUS: Proportion of non-retail business acres per town.
#
# CHAS: Charles River dummy variable (1 if the suburb bounds the river; otherwise, 0).
#
# NOX: Nitric oxide concentration (parts per 10 million).
#
# RM: Average number of rooms per dwelling.
#
# AGE: Proportion of owner-occupied units built before 1940.
#
# DIS: Weighted distances to five Boston employment centers.
#
# RAD: Index of accessibility to radial highways.
#
# TAX: Full-value property tax rate per $10,000.
#
# PTRATIO: Pupil-teacher ratio by town.
# B: 1000(Bk - 0.63)^2, where Bk is the proportion of Black people by town.
#
# LSTAT: Percentage of lower status of the population.
#
# The target variable, which is the variable we aim to predict, is the median value of owner-occupied homes in $1000s (MEDV).

# %%
df['MEDV']
# Out:
# 0      24.0
# 1      21.6
# 2      34.7
# 3      33.4
# 4      36.2
#        ...
# 501    22.4
# 502    20.6
# 503    23.9
# 504    22.0
# 505    11.9
# Name: MEDV, Length: 506, dtype: float64

# %%
X = df.drop(columns = 'MEDV', axis = 1)
y = df['MEDV']

# %%
X.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT
# 0     15.3  396.90   4.98
# 1     17.8  396.90   9.14
# 2     17.8  392.83   4.03
# 3     18.7  394.63   2.94
# 4     18.7  396.90   5.33

# %%
y.head()
# Out:
# 0    24.0
# 1    21.6
# 2    34.7
# 3    33.4
# 4    36.2
# Name: MEDV, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=101)

# %%
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (404, 13)
# (404,)
# (102, 13)
# (102,)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train,y_train)

print("Coefficients: ",model.coef_)
print("Intercept: ",model.intercept_)
# Out:
# Coefficients:  [-9.89913563e-02  4.25047578e-02  1.67390094e-02  3.06437882e+00
#  -1.56462528e+01  4.01888422e+00 -8.31558474e-04 -1.44628034e+00
#   2.67827281e-01 -1.04725485e-02 -8.88651815e-01  8.25262805e-03
#  -5.49367192e-01]
# Intercept:  32.90613090863728

# %%
y_pred = model.predict(X_test)

from sklearn.metrics import mean_absolute_error,mean_squared_error,

MAE = mean_absolute_error(y_test,y_pred)
MSE = mean_squared_error(y_test,y_pred)
print("mean absolute error: ",MAE)
print("mean squared error: ",MSE)
print("Root mean squared error: ",np.sqrt(MSE))
# Out:
# mean absolute error:  3.999404253053898
# mean squared error:  33.26891855791992
# Root mean squared error:  5.767921511074844

# %%
from sklearn.metrics import r2_score

# %%
# Compute total sum of squares (TSS) around the actual values mean
TSS = np.sum((y_test-np.mean(y_test))**2)
print("TSS: ",TSS)
# Compute Sum of Squares of Residuals (SSR)
SSR = np.sum((y_test-y_pred)**2)
print("SSR: ",SSR)
# Compute the coefficient of determination (R^2) (R-squared)
r_squared = 1-(SSR/TSS)
print("R-Squared: ",r_squared)
# Out:
# TSS:  11443.50205882353
# SSR:  3393.429692907832
# R-Squared:  0.7034623076515879

# %%
print("R-Squared",r2_score(y_test,y_pred))
# Out:
# R-Squared 0.7034623076515879

# %%
X_test.shape
# Out:
# (102, 13)

# %%
# Compute adjusted R-Squared
n = X_test.shape[0]
p = X_test.shape[1]
adjusted_r_squared = 1 - ((1-r_squared)*(n-1))/(n-p-1)
print("Adjusted R2 Score is: ",adjusted_r_squared)
# Out:
# Adjusted R2 Score is:  0.659655603100118
