# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
from matplotlib import pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('/kaggle/input/predict-online-dating-matches-dataset/Online_Dating_Behavior_Dataset.csv')

# %%
df.head()
# Out:
#    Gender  PurchasedVIP  Income  Children  Age  Attractiveness  Matches
# 0       0             1   51777         3   47               5       70
# 1       1             0   36646         0   42               7      130
# 2       0             0   53801         1   25               5        0
# 3       0             0   56105         0   35               8        0
# 4       0             0   55597         1   36               6        0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Gender          1000 non-null   int64
#  1   PurchasedVIP    1000 non-null   int64
#  2   Income          1000 non-null   int64
#  3   Children        1000 non-null   int64
#  4   Age             1000 non-null   int64
#  5   Attractiveness  1000 non-null   int64
#  6   Matches         1000 non-null   int64
# dtypes: int64(7)
# memory usage: 54.8 KB

# %%
df['Gender'].value_counts() # 0 - Male, 1 - Female
# Out:
# Gender
# 1    510
# 0    490
# Name: count, dtype: int64

# %%
df['PurchasedVIP'].value_counts() # 0 - No, 1 - Yes
# Out:
# PurchasedVIP
# 0    526
# 1    474
# Name: count, dtype: int64

# %%
df['Children'].value_counts() # No of Children (0-3)
# Out:
# Children
# 0    412
# 1    294
# 2    198
# 3     96
# Name: count, dtype: int64

# %%
df['Attractiveness'].value_counts() # Range: 1-10
# Out:
# Attractiveness
# 6     116
# 7     115
# 10    106
# 9     104
# 3     104
# 4     104
# 2      94
# 5      88
# 8      86
# 1      83
# Name: count, dtype: int64

# %%
df['Matches'].value_counts() # No of various matches got how many people e.g. 70 matches got by 267 people
# Out:
# Matches
# 70     267
# 0      259
# 130     64
# 150     61
# 100     61
# 120     58
# 160     53
# 80      48
# 90      47
# 140     42
# 110     40
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# Gender            0
# PurchasedVIP      0
# Income            0
# Children          0
# Age               0
# Attractiveness    0
# Matches           0
# dtype: int64

# %%
sns.pairplot(df)

# %%
sns.scatterplot(data = df, y = 'Income', x = 'Matches')
# Out:
# <Axes: xlabel='Matches', ylabel='Income'>

# %%
sns.scatterplot(data = df, x = 'Age', y = 'Matches')
# Out:
# <Axes: xlabel='Age', ylabel='Matches'>

# %%
sns.scatterplot(data = df, x = 'Children', y = 'Matches')
# Out:
# <Axes: xlabel='Children', ylabel='Matches'>

# %%
sns.kdeplot(data = df, x = 'Income', y = 'Matches')
# Out:
# <Axes: xlabel='Income', ylabel='Matches'>

# %% [markdown]
# Income Range for getting matches --> More than 28K, due to outliers, boxplot is necessery

# %%
sns.kdeplot(data = df, x = 'Attractiveness', y = 'Matches')
# Out:
# <Axes: xlabel='Attractiveness', ylabel='Matches'>

# %%
sns.boxplot(data = df, y = 'Income', x = 'Matches')
# Out:
# <Axes: xlabel='Matches', ylabel='Income'>

# %% [markdown]
# Outliers are probably the ghost users

# %% [markdown]
# Income Range for getting Matches -> More than 43K, median value for 70 matches is 50K

# %%
sns.boxplot(data = df, y = 'Attractiveness', x = 'Matches')
# Out:
# <Axes: xlabel='Matches', ylabel='Attractiveness'>

# %% [markdown]
# Even though they are attractiveness of median = 6 why they have zero matches?

# %%
sns.scatterplot(data = df, y = 'Income', x = 'Matches', hue = 'Attractiveness',legend = 'brief')
# Out:
# <Axes: xlabel='Matches', ylabel='Income'>

# %%
sns.boxplot(data = df, y = 'Children', x = 'Matches')
# Out:
# <Axes: xlabel='Matches', ylabel='Children'>

# %%
sns.boxplot(data = df, x = 'Gender', y = 'Matches') # 0 - Male, 1 - Female
# Out:
# <Axes: xlabel='Gender', ylabel='Matches'>

# %%
sns.scatterplot(data = df, x = 'PurchasedVIP', y = 'Matches')
# Out:
# <Axes: xlabel='PurchasedVIP', ylabel='Matches'>

# %%
sns.boxplot(data = df, x = 'PurchasedVIP', y = 'Matches')
# Out:
# <Axes: xlabel='PurchasedVIP', ylabel='Matches'>

# %%
df['Matches'] = df['Matches'].astype(np.float64)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Gender          1000 non-null   int64
#  1   PurchasedVIP    1000 non-null   int64
#  2   Income          1000 non-null   int64
#  3   Children        1000 non-null   int64
#  4   Age             1000 non-null   int64
#  5   Attractiveness  1000 non-null   int64
#  6   Matches         1000 non-null   float64
# dtypes: float64(1), int64(6)
# memory usage: 54.8 KB

# %%
sns.displot(data = df,x = 'Matches')

# %%
df.head()
# Out:
#    Gender  PurchasedVIP  Income  Children  Age  Attractiveness  Matches
# 0       0             1   51777         3   47               5     70.0
# 1       1             0   36646         0   42               7    130.0
# 2       0             0   53801         1   25               5      0.0
# 3       0             0   56105         0   35               8      0.0
# 4       0             0   55597         1   36               6      0.0
