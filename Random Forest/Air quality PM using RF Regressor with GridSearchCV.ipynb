# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Ethans/Datasets/Real_Combine.csv')

# %%
df.head()
# Out:
#       T    TM   Tm     SLP     H   VV    V    VM      PM 2.5
# 0   7.4   9.8  4.8  1017.6  93.0  0.5  4.3   9.4  219.720833
# 1   7.8  12.7  4.4  1018.5  87.0  0.6  4.4  11.1  182.187500
# 2   6.7  13.4  2.4  1019.4  82.0  0.6  4.8  11.1  154.037500
# 3   8.6  15.5  3.3  1018.7  72.0  0.8  8.1  20.6  223.208333
# 4  12.4  20.9  4.4  1017.3  61.0  1.3  8.7  22.2  200.645833

# %% [markdown]
# **Dataset Description**
#
# # T == Average Temperature (°C)
#
# # TM == Maximum temperature (°C)
#
# # Tm == Minimum temperature (°C)
#
# # SLP == Atmospheric pressure at sea level (hPa)
#
# # H == Average relative humidity (%)
#
# # VV == Average visibility (Km)
#
# # V == Average wind speed (Km/h)
#
# # VM == Maximum sustained wind speed (Km/h)
#
# # PM2.5== Fine particulate matter (PM2.5) is an air pollutant that is a concern for people's health when levels in air are high
#
# **PM2.5 is the Target variable**

# %%
df.tail()
# Out:
#          T    TM    Tm     SLP     H   VV     V    VM      PM 2.5
# 1088  18.1  24.0  11.2  1015.4  56.0  1.8  15.9  25.9  288.416667
# 1089  17.8  25.0  10.7  1015.8  54.0  2.3   9.4  22.2  256.833333
# 1090  13.9  24.5  11.4  1015.0  95.0  0.6   8.7  14.8  169.000000
# 1091  16.3  23.0   9.8  1016.9  78.0  1.1   7.4  16.5  186.041667
# 1092  16.3  23.4   9.0  1017.3  68.0  1.3   7.8  18.3  185.583333

# %%
# To get statistical data
df.describe()
# Out:
#                  T           TM           Tm          SLP            H  \
# count  1093.000000  1093.000000  1093.000000  1093.000000  1093.000000
# mean     26.009241    32.482251    19.460201  1008.081885    62.918573
# std       7.237401     6.679078     7.438653     7.529237    15.709816
# min       6.700000     9.800000     0.000000   991.500000    20.000000
# 25%      19.300000    27.800000    12.100000  1001.100000    54.000000
# 50%      28.200000    34.200000    21.200000  1008.100000    64.000000
# 75%      31.700000    37.000000    26.000000  1015.000000    74.000000
# max      38.500000    45.500000    32.700000  1023.200000    98.000000
#
#                 VV            V           VM       PM 2.5
# count  1093.000000  1093.000000  1093.000000  1092.000000
# mean      2.003111     6.751510    15.805124   109.090984
# std       0.747541     3.841137     7.308435    84.465790
# min       0.300000     0.400000     1.900000     0.000000
# 25%       1.600000     3.700000    11.100000    41.833333
# 50%       1.900000     6.500000    14.800000    83.458333
# 75%       2.600000     9.100000    18.300000   158.291667
# max       5.800000    24.400000    57.600000   404.500000

# %%
df.isnull().sum()
# Out:
# T         0
# TM        0
# Tm        0
# SLP       0
# H         0
# VV        0
# V         0
# VM        0
# PM 2.5    1
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1093 entries, 0 to 1092
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   T       1093 non-null   float64
#  1   TM      1093 non-null   float64
#  2   Tm      1093 non-null   float64
#  3   SLP     1093 non-null   float64
#  4   H       1093 non-null   float64
#  5   VV      1093 non-null   float64
#  6   V       1093 non-null   float64
#  7   VM      1093 non-null   float64
#  8   PM 2.5  1092 non-null   float64
# dtypes: float64(9)
# memory usage: 77.0 KB

# %%
# Repalcing the nan value with the mean value
mean_value = df['PM 2.5'].mean()
df['PM 2.5'] = df['PM 2.5'].fillna(mean_value)

# %%
df.isnull().sum()
# Out:
# T         0
# TM        0
# Tm        0
# SLP       0
# H         0
# VV        0
# V         0
# VM        0
# PM 2.5    0
# dtype: int64

# %%
relation = df.corr()
relation_index = relation.index

# %%
relation
# Out:
#                T        TM        Tm       SLP         H        VV         V  \
# T       1.000000  0.967570  0.953703 -0.881698 -0.510593  0.640738  0.302349
# TM      0.967570  1.000000  0.891970 -0.823447 -0.588017  0.606746  0.293309
# Tm      0.953703  0.891970  1.000000 -0.917557 -0.288647  0.577382  0.296546
# SLP    -0.881698 -0.823447 -0.917557  1.000000  0.242307 -0.518015 -0.330155
# H      -0.510593 -0.588017 -0.288647  0.242307  1.000000 -0.465514 -0.380805
# VV      0.640738  0.606746  0.577382 -0.518015 -0.465514  1.000000  0.377029
# V       0.302349  0.293309  0.296546 -0.330155 -0.380805  0.377029  1.000000
# VM      0.288292  0.297590  0.267249 -0.311231 -0.362632  0.342650  0.775715
# PM 2.5 -0.630705 -0.567378 -0.673415  0.622410  0.137802 -0.573864 -0.268498
#
#               VM    PM 2.5
# T       0.288292 -0.630705
# TM      0.297590 -0.567378
# Tm      0.267249 -0.673415
# SLP    -0.311231  0.622410
# H      -0.362632  0.137802
# VV      0.342650 -0.573864
# V       0.775715 -0.268498
# VM      1.000000 -0.215813
# PM 2.5 -0.215813  1.000000

# %%
relation_index
# Out:
# Index(['T', 'TM', 'Tm', 'SLP', 'H', 'VV', 'V', 'VM', 'PM 2.5'], dtype='object')

# %%
# Feature Scaling using Standard Scaler
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
df.iloc[:,:-1] = scaler.fit_transform(df.iloc[:,:-1])

# %%
# After Scaling
df.head()
# Out:
#           T        TM        Tm       SLP         H        VV         V  \
# 0 -2.572437 -3.397570 -1.971716  1.264733  1.915694 -2.011660 -0.638517
# 1 -2.517143 -2.963179 -2.025514  1.384321  1.533592 -1.877826 -0.612471
# 2 -2.669201 -2.858326 -2.294503  1.503910  1.215174 -1.877826 -0.508288
# 3 -2.406556 -2.543768 -2.173458  1.410897  0.578338 -1.610160  0.351226
# 4 -1.881265 -1.734903 -2.025514  1.224870 -0.122182 -0.940995  0.507501
#
#          VM      PM 2.5
# 0 -0.876803  219.720833
# 1 -0.644088  182.187500
# 2 -0.644088  154.037500
# 3  0.656375  223.208333
# 4  0.875400  200.645833

# %%
# Train Test Splitting the data
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df.iloc[:,:-1], df.iloc[:,-1], test_size=0.20, random_state=101)

# %%
X_train.shape
# Out:
# (874, 8)

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
reg_rf_model = RandomForestRegressor()
reg_rf_model.fit(X_train,y_train)
# Out:
# RandomForestRegressor()

# %%
y_pred = reg_rf_model.predict(X_test)

# %%
reg_rf_model.score(X_test,y_test)
# Out:
# 0.8160819006052049

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %%
MAE = mean_absolute_error(y_test,y_pred)
MSE = mean_squared_error(y_test,y_pred)
RMSE = np.sqrt(MSE)
R2 = r2_score(y_test,y_pred)
print("Mean Absolute Error: ",MAE)
print("Mean Squared Error: ",MSE)
print("Root Mean Squared Error: ",RMSE)
print("R2 Score: ",R2)
# Out:
# Mean Absolute Error:  23.292472237902892
# Mean Squared Error:  1458.7233087171057
# Root Mean Squared Error:  38.193236426324304
# R2 Score:  0.8160819006052049

# %%
# Hyperparameter Tuning
from sklearn.model_selection import GridSearchCV

# %%
# Hyper parameters range initialisation for Tuning
parameters = {"n_estimators":[90,100,120,150],
              "max_depth":[1,3,5,7],
              "min_samples_leaf":[1,2,3,4],
              "min_weight_fraction_leaf":[0.1,0.2,0.3,0.4],
              "max_features":["sqrt", "log2"],
              "max_leaf_nodes":[None,10,20,30]}

# %%
tuned_model = GridSearchCV(reg_rf_model,param_grid = parameters,scoring = 'neg_mean_squared_error',cv = 5,verbose = 3)

# %%
X = df.iloc[:,:-1]
y = df.iloc[:,-1]

# %%
tuned_model.fit(X,y)
# Out:
# Streaming output truncated to the last 5000 lines.
# [CV 1/5] END max_depth=5, max_features=sqrt, max_leaf_nodes=None, min_samples_leaf=2, min_weight_fraction_leaf=0.3, n_estimators=90;, score=-4208.993 total time=   0.1s
# [CV 2/5] END max_depth=5, max_features=sqrt, max_leaf_nodes=None, min_samples_leaf=2, min_weight_fraction_leaf=0.3, n_estimators=90;, score=-2982.343 total time=   0.1s
# [CV 3/5] END max_depth=5, max_features=sqrt, max_leaf_nodes=None, min_samples_leaf=2, min_weight_fraction_leaf=0.3, n_estimators=90;, score=-3223.449 total time=   0.1s
# [CV 4/5] END max_depth=5, max_features=sqrt, max_leaf_nodes=None, min_samples_leaf=2, min_weight_fraction_leaf=0.3, n_estimators=90;, score=-3590.863 total time=   0.1s
# [CV 5/5] END max_depth=5, max_features=sqrt, max_leaf_nodes=None, min_samples_leaf=2, min_weight_fraction_leaf=0.3, n_estimators=90;, score=-5237.899 total time=   0.1s
# [CV 1/5] END max_depth=5, max_features=sqrt, max_leaf_nodes=None, min_samples_leaf=2, min_weight_fraction_leaf=0.3, n_estimators=100;, score=-4260.787 total time=   0.2s
# [CV 2/5] END max_depth=5, max_features=sqrt, max_leaf_nodes=None, min_samples_leaf=2, min_weight_fraction_leaf=0.3, n_estimators=100;, score=-3017.419 total time=   0.2s
# [CV 3/5] END max_depth=5, max_features=sqrt, max_leaf_nodes=None, min_samples_leaf=2, min_weight_fraction_leaf=0.3, n_estimators=100;, score=-3240.595 total time=   0.2s
# [CV 4/5] END max_depth=5, max_features=sqrt, max_leaf_nodes=None, min_samples_leaf=2, min_weight_fraction_leaf=0.3, n_estimators=100;, score=-3655.576 total time=   0.2s
# [CV 5/5] END max_depth=5, max_features=sqrt, max_leaf_nodes=None, min_samples_leaf=2, min_weight_fraction_leaf=0.3, n_estimators=100;, score=-5152.897 total time=   0.2s
# [CV 1/5] END max_depth=5, max_features=sqrt, max_leaf_nodes=None, min_samples_leaf=2, min_weight_fraction_leaf=0.3, n_estimators=120;, score=-4221.810 total time=   0.2s
# [CV 2/5] END max_depth=5, max_features=sqrt, max_leaf_nodes=None, min_samples_leaf=2, min_weight_fraction_leaf=0.3, n_estimators=120;, score=-3087.997 total time=   0.2s
# [CV 3/5] END max_depth=5, max_features=sqrt, max_leaf_nodes=None, min_samples_leaf=2, min_weight_fraction_leaf=0.3, n_estimators=120;, score=-3222.065 total time=   0.2s
# [CV 4/5] END max_depth=5, max_features=sqrt, max_leaf_nodes=None, min_samples_leaf=2, min_weight_fraction_leaf=0.3, n_estimators=120;, score=-3605.191 total time=   0.2s
# [CV 5/5] END max_depth=5, max_features=sqrt, max_leaf_nodes=None, min_samples_leaf=2, min_weight_fraction_leaf=0.3, n_estimators=120;, score=-5136.983 total time=   0.2s
# [CV 1/5] END max_depth=5, max_features=sqrt, max_leaf_nodes=None, min_samples_leaf=2, min_weight_fraction_leaf=0.3, n_estimators=150;, score=-4166.220 total time=   0.3s
# [CV 2/5] END max_depth=5, max_features=sqrt, max_leaf_nodes=None, min_samples_leaf=2, min_weight_fraction_leaf=0.3, n_estimators=150;, score=-2986.049 total time=   0.2s
# [CV 3/5] END max_depth=5, max_features=sqrt, max_leaf_nodes=None, min_samples_leaf=2, min_weight_fraction_leaf=0.3, n_estimators=150;, score=-3165.288 total time=   0.2s
# [CV 4/5] END max_depth=5, max_features=sqrt, max_leaf_nodes=None, min_samples_leaf=2, min_weight_fraction_leaf=0.3, n_estimators=150;, score=-3633.450 total time=   0.2s
# [CV 5/5] END max_depth=5, max_features=sqrt, max_leaf_nodes=None, min_samples_leaf=2, min_weight_fraction_leaf=0.3, n_estimators=150;, score=-5323.614 total time=   0.2s
# [CV 1/5] END max_depth=5, max_features=sqrt, max_leaf_nodes=None, min_samples_leaf=2, min_weight_fraction_leaf=0.4, n_estimators=90;, score=-4369.078 total time=   0.1s
# [CV 2/5] END max_depth=5, max_features=sqrt, max_leaf_nodes=None, min_samples_leaf=2, min_weight_fraction_leaf=0.4, n_estimators=90;, score=-2932.432 total time=   0.1s
# [CV 3/5] END max_depth=5, max_features=sqrt, max_leaf_nodes=None, min_samples_leaf=2, min_weight_fraction_leaf=0.4, n_estimators=90;, score=-3371.380 total time=   0.1s
# [CV 4/5] END max_depth=5, max_features=sqrt, max_leaf_nodes=None, min_samples_leaf=2, min_weight_fraction_leaf=0.4, n_estimators=90;, score=-3978.009 total time=   0.1s
# [CV 5/5] END max_depth=5, max_features=sqrt, max_leaf_nodes=None, min_samples_leaf=2, min_weight_fraction_leaf=0.4, n_estimators=90;, score=-5542.384 total time=   0.1s
# [CV 1/5] END max_depth=5, max_features=sqrt, max_leaf_nodes=None, min_samples_leaf=2, min_weight_fraction_leaf=0.4, n_estimators=100;, score=-4464.057 total time=   0.2s
# [CV 2/5] END max_depth=5, max_features=sqrt, max_leaf_nodes=None, min_samples_leaf=2, min_weight_fraction_leaf=0.4, n_estimators=100;, score=-3003.191 total time=   0.2s
# [CV 3/5] END max_depth=5, max_features=sqrt, max_leaf_nodes=None, min_samples_leaf=2, min_weight_fraction_leaf=0.4, n_estimators=100;, score=-3514.290 total time=   0.2s
# [CV 4/5] END max_depth=5, max_features=sqrt, max_leaf_nodes=None, min_samples_leaf=2, min_weight_fraction_leaf=0.4, n_estimators=100;, score=-3953.619 total time=   0.1s
# [CV 5/5] END max_depth=5, max_features=sqrt, max_leaf_nodes=None, min_samples_leaf=2, min_weight_fraction_leaf=0.4, n_estimators=100;, score=-5755.709 total time=   0.2s
# [CV 1/5] END max_depth=5, max_features=sqrt, max_leaf_nodes=None, min_samples_leaf=2, min_weight_fraction_leaf=0.4, n_estimators=120;, score=-4425.686 total time=   0.2s
# [CV 2/5] END max_depth=5, max_features=sqrt, max_leaf_nodes=None, min_samples_leaf=2, min_weight_fraction_leaf=0.4, n_estimators=120;, score=-2907.492 total time=   0.2s
# [CV 3/5] END max_depth=5, max_features=sqrt, max_leaf_nodes=None, min_samples_leaf=2, min_weight_fraction_leaf=0.4, n_estimators=120;, score=-3472.744 total time=   0.2s
# [CV 4/5] END max_depth=5, max_features=sqrt, max_leaf_nodes=None, min_samples_leaf=2, min_weight_fraction_leaf=0.4, n_estimators=120;, score=-
total time=   0.2s
# [CV 2/5] END max_depth=5, max_features=sqrt, max_leaf_nodes=10, min_samples_leaf=1, min_weight_fraction_leaf=0.4, n_estimators=150;, score=-2967.982 total time=   0.2s
# [CV 3/5] END max_depth=5, max_features=sqrt, max_leaf_nodes=10, min_samples_leaf=1, min_weight_fraction_leaf=0.4, n_estimators=150;, score=-3479.478 total time=   0.2s
# [CV 4/5] END max_depth=5, max_features=sqrt, max_leaf_nodes=10, min_samples_leaf=1, min_weight_fraction_leaf=0.4, n_estimators=150;, score=-3921.441 total time=   0.2s
# [CV 5/5] END max_depth=5, max_features=sqrt, max_leaf_nodes=10, min_samples_leaf=1, min_weight_fraction_leaf=0.4, n_estimators=150;, score=-5702.554 total time=   0.2s
# [CV 1/5] END max_depth=5, max_features=sqrt, max_leaf_nodes=10, min_samples_leaf=2, min_weight_fraction_leaf=0.1, n_estimators=90;, score=-3761.083 total time=   0.1s
# [CV 2/5] END max_depth=5, max_features=sqrt, max_leaf_nodes=10, min_samples_leaf=2, min_weight_fraction_leaf=0.1, n_estimators=90;, score=-2668.440 total time=   0.1s
# [CV 3/5] END max_depth=5, max_features=sqrt, max_leaf_nodes=10, min_samples_leaf=2, min_weight_fraction_leaf=0.1, n_estimators=90;, score=-2678.198 total time=   0.2s
# ...
# [CV 4/5] END max_depth=7, max_features=log2, max_leaf_nodes=30, min_samples_leaf=3, min_weight_fraction_leaf=0.4, n_estimators=100;, score=-3701.123 total time=   0.2s
# [CV 5/5] END max_depth=7, max_features=log2, max_leaf_nodes=30, min_samples_leaf=3, min_weight_fraction_leaf=0.4, n_estimators=100;, score=-5234.244 total time=   0.2s
# [CV 1/5] END max_depth=7, max_features=log2, max_leaf_nodes=30, min_samples_leaf=3, min_weight_fraction_leaf=0.4, n_estimators=120;, score=-4359.143 total time=   0.3s
# [CV 2/5] END max_depth=7, max_features=log2, max_leaf_nodes=30, min_samples_leaf=3, min_weight_fraction_leaf=0.4, n_estimators=120;, score=-3091.711 total time=   0.3s
# [CV 3/5] END max_depth=7, max_features=log2, max_leaf_nodes=30, min_samples_leaf=3, min_weight_fraction_leaf=0.4, n_estimators=120;, score=-3296.753 total time=   0.3s
# [CV 4/5] END max_depth=7, max_features=log2, max_leaf_nodes=30, min_samples_leaf=3, min_weight_fraction_leaf=0.4, n_estimators=120;, score=-3693.704 total time=   0.3s
# [CV 5/5] END max_depth=7, max_features=log2, max_leaf_nodes=30, min_samples_leaf=3, min_weight_fraction_leaf=0.4, n_estimators=120;, score=-5255.051 total time=   0.3s
# [CV 1/5] END max_depth=7, max_features=log2, max_leaf_nodes=30, min_samples_leaf=3, min_weight_fraction_leaf=0.4, n_estimators=150;, score=-4420.534 total time=   0.3s
# [CV 2/5] END max_depth=7, max_features=log2, max_leaf_nodes=30, min_samples_leaf=3, min_weight_fraction_leaf=0.4, n_estimators=150;, score=-3269.910 total time=   0.4s
# [CV 3/5] END max_depth=7, max_features=log2, max_leaf_nodes=30, min_samples_leaf=3, min_weight_fraction_leaf=0.4, n_estimators=150;, score=-3291.622 total time=   0.4s
# [CV 4/5] END max_depth=7, max_features=log2, max_leaf_nodes=30, min_samples_leaf=3, min_weight_fraction_leaf=0.4, n_estimators=150;, score=-3669.668 total time=   0.4s
# [CV 5/5] END max_depth=7, max_features=log2, max_leaf_nodes=30, min_samples_leaf=3, min_weight_fraction_leaf=0.4, n_estimators=150;, score=-5328.440 total time=   0.4s
# [CV 1/5] END max_depth=7, max_features=log2, max_leaf_nodes=30, min_samples_leaf=4, min_weight_fraction_leaf=0.1, n_estimators=90;, score=-3745.204 total time=   0.2s
# [CV 2/5] END max_depth=7, max_features=log2, max_leaf_nodes=30, min_samples_leaf=4, min_weight_fraction_leaf=0.1, n_estimators=90;, score=-2819.001 total time=   0.2s
# [CV 3/5] END max_depth=7, max_features=log2, max_leaf_nodes=30, min_samples_leaf=4, min_weight_fraction_leaf=0.1, n_estimators=90;, score=-2626.545 total time=   0.2s
# [CV 4/5] END max_depth=7, max_features=log2, max_leaf_nodes=30, min_samples_leaf=4, min_weight_fraction_leaf=0.1, n_estimators=90;, score=-2897.410 total time=   0.2s
# [CV 5/5] END max_depth=7, max_features=log2, max_leaf_nodes=30, min_samples_leaf=4, min_weight_fraction_leaf=0.1, n_estimators=90;, score=-4630.599 total time=   0.2s
# [CV 1/5] END max_depth=7, max_features=log2, max_leaf_nodes=30, min_samples_leaf=4, min_weight_fraction_leaf=0.1, n_estimators=100;, score=-3775.393 total time=   0.2s
# [CV 2/5] END max_depth=7, max_features=log2, max_leaf_nodes=30, min_samples_leaf=4, min_weight_fraction_leaf=0.1, n_estimators=100;, score=-2812.011 total time=   0.2s
# [CV 3/5] END max_depth=7, max_features=log2, max_leaf_nodes=30, min_samples_leaf=4, min_weight_fraction_leaf=0.1, n_estimators=100;, score=-2636.083 total time=   0.2s
# [CV 4/5] END max_depth=7, max_features=log2, max_leaf_nodes=30, min_samples_leaf=4, min_weight_fraction_leaf=0.1, n_estimators=100;, score=-2880.635 total time=   0.2s
# [CV 5/5] END max_depth=7, max_features=log2, max_leaf_nodes=30, min_samples_leaf=4, min_weight_fraction_leaf=0.1, n_estimators=100;, score=-4551.089 total time=   0.2s
# [CV 1/5] END max_depth=7, max_features=log2, max_leaf_nodes=30, min_samples_leaf=4, min_weight_fraction_leaf=0.1, n_estimators=120;, score=-3720.824 total time=   0.2s
# [CV 2/5] END max_depth=7, max_features=log2, max_leaf_nodes=30, min_samples_leaf=4, min_weight_fraction_leaf=0.1, n_estimators=120;, score=-2885.263 total time=   0.2s
# [CV 3/5] END max_depth=7, max_features=log2, max_leaf_nodes=30, min_samples_leaf=4, min_weight_fraction_leaf=0.1, n_estimators=120;, score=-2618.467 total time=   0.2s
# [CV 4/5] END max_depth=7, max_features=log2, max_leaf_nodes=30, min_samples_leaf=4, min_weight_fraction_leaf=0.1, n_estimators=120;, score=-2902.166 total time=   0.2s
# [CV 5/5] END max_depth=7, max_features=log2, max_leaf_nodes=30, min_samples_leaf=4, min_weight_fraction_leaf=0.1, n_estimators=120;, score=-4592.776 total time=   0.2s
# [CV 1/5] END max_depth=7, max_features=log2, max_leaf_nodes=30, min_samples_leaf=4, min_weight_fraction_leaf=0.1, n_estimators=150;, score=-3696.110 total time=   0.3s
# [CV 2/5] END max_depth=7, max_features=log2, max_leaf_nodes=30, min_samples_leaf=4, min_weight_fraction_leaf=0.1, n_estimators=150;, score=-2883.919 total time=   0.3s
# [CV 3/5] END max_depth=7, max_features=log2, max_leaf_nodes=30, min_samples_leaf=4, min_weight_fraction_leaf=0.1, n_estimators=150;, score=-2620.394 total time=   0.3s
# [CV 4/5] END max_depth=7, max_features=log2, max_leaf_nodes=30, min_samples_leaf=4, min_weight_fraction_leaf=0.1, n_estimators=150;, score=-2893.087 total time=   0.3s
# [CV 5/5] END max_depth=7, max_features=log2, max_leaf_nodes=30, min_samples_leaf=4, min_weight_fraction_leaf=0.1, n_estimators=150;, score=-4631.759 total time=   0.3s
# [CV 1/5] END max_depth=7, max_features=log2, max_leaf_nodes=30, min_samples_leaf=4, min_weight_fraction_leaf=0.2, n_estimators=90;, score=-4151.469 total time=   0.2s
# [CV 2/5] END max_depth=7, max_features=log2, max_leaf_nodes=30, min_samples_leaf=4, min_weight_fraction_leaf=0.2, n_estimators=90;, score=-3137.670 total time=   0.2s
# [CV 3/5] END max_depth=7, max_features=log2, max_leaf_nodes=30, min_samples_leaf=4, min_weight_fraction_leaf=0.2, n_estimators=90;, score=-2851.723 total time=   0.1s
# [CV 4/5] END max_depth=7, max_features=log2, max_leaf_nodes=30, min_samples_leaf=4, min_weight_fraction_leaf=0.2, n_estimators=90;, score=-3254.826 total time=   0.2s
# [CV 5/5] END max_depth=7, max_features=log2, max_leaf_nodes=30, min_samples_leaf=4, min_weight_fraction_leaf=0.2, n_estimators=90;, score=-4838.590 total time=   0.1s
# [CV 1/5] END max_depth=7, max_features=log2, max_leaf_nodes=30, min_samples_leaf=4, min_weight_fraction_leaf=0.2, n_estimators=100;, score=-4056.911 total time=   0.2s
# [CV 2/5] END max_depth=7, max_features=log2, max_leaf_nodes=30, min_samples_leaf=4, min_weight_fraction_leaf=0.2, n_estimators=100;, score=-3172.038 total time=   0.2s
# [CV 3/5] END max_depth=7, max_features=log2, max_leaf_nodes=30, min_samples_leaf=4, min_weight_fraction_leaf=0.2, n_estimators=100;, score=-2889.618 total time=   0.2s
# [CV 4/5] END max_depth=7, max_features=log2, max_leaf_nodes=30, min_samples_leaf=4, min_weight_fraction_leaf=0.2, n_estimators=100;, score=-3226.791 total time=   0.2s
# [CV 5/5] END max_depth=7, max_features=log2, max_leaf_nodes=30, min_samples_leaf=4, min_weight_fraction_leaf=0.2, n_estimators=100;, score=-4891.136 total time=   0.2s
# [CV 1/5] END max_depth=7, max_features=log2, max_leaf_nodes=30, min_samples_leaf=4, min_weight_fraction_leaf=0.2, n_estimators=120;, score=-4139.636 total time=   0.2s
# [CV 2/5] END max_depth=7, max_features=log2, max_leaf_nodes=30, min_samples_leaf=4, min_weight_fraction_leaf=0.2, n_estimators=120;, score=-3220.517 total time=   0.2s
# [CV 3/5] END max_depth=7, max_features=log2, max_leaf_nodes=30, min_samples_leaf=4, min_weight_fraction_leaf=0.2, n_estimators=120;, score=-2853.704 total time=   0.2s
# [CV 4/5] END max_depth=7, max_features=log2, max_leaf_nodes=30, min_samples_leaf=4, min_weight_fraction_leaf=0.2, n_estimators=120;, score=-3253.060 total time=   0.2s
# [CV 5/5] END max_depth=7, max_features=log2, max_leaf_nodes=30, min_samples_leaf=4, min_weight_fraction_leaf=0.2, n_estimators=120;, score=-4862.665 total time=   0.2s
# [CV 1/5] END max_depth=7, max_features=log2, max_leaf_nodes=30, min_samples_leaf=4, min_weight_fraction_leaf=0.2, n_estimators=150;, score=-4039.255 total time=   0.3s
# [CV 2/5] END max_depth=7, max_features=log2, max_leaf_nodes=30, min_samples_leaf=4, min_weight_fraction_leaf=0.2, n_estimators=150;, score=-2971.526 total time=   0.2s
# [CV 3/5] END max_depth=7, max_features=log2, max_leaf_nodes=30, min_samples_leaf=4, min_weight_fraction_leaf=0.2, n_estimators=150;, score=-2898.172 total time=   0.3s
# [CV 4/5] END max_depth=7, max_features=log2, max_leaf_nodes=30, min_samples_leaf=4, min_weight_fraction_leaf=0.2, n_estimators=150;, score=-3241.117 total time=   0.3s
# [CV 5/5] END max_depth=7, max_features=log2, max_leaf_nodes=30, min_samples_leaf=4, min_weight_fraction_leaf=0.2, n_estimators=150;, score=-4846.256 total time=   0.3s
# [CV 1/5] END max_depth=7, max_features=log2, max_leaf_nodes=30, min_samples_leaf=4, min_weight_fraction_leaf=0.3, n_estimators=90;, score=-4229.510 total time=   0.1s
# [CV 2/5] END max_depth=7, max_features=log2, max_leaf_nodes=30, min_samples_leaf=4, min_weight_fraction_leaf=0.3, n_estimators=90;, score=-3206.071 total time=   0.1s
# [CV 3/5] END max_depth=7, max_features=log2, max_leaf_nodes=30, min_samples_leaf=4, min_weight_fraction_leaf=0.3, n_estimators=90;, score=-3064.267 total time=   0.1s
# [CV 4/5] END max_depth=7, max_features=log2, max_leaf_nodes=30, min_samples_leaf=4, min_weight_fraction_leaf=0.3, n_estimators=90;, score=-3509.020 total time=   0.1s
# [CV 5/5] END max_depth=7, max_features=log2, max_leaf_nodes=30, min_samples_leaf=4, min_weight_fraction_leaf=0.3, n_estimators=90;, score=-4934.964 total time=   0.1s
# [CV 1/5] END max_depth=7, max_features=log2, max_leaf_nodes=30, min_samples_leaf=4, min_weight_fraction_leaf=0.3, n_estimators=100;, score=-4210.310 total time=   0.2s
# [CV 2/5] END max_depth=7, max_features=log2, max_leaf_nodes=30, min_samples_leaf=4, min_weight_fraction_leaf=0.3, n_estimators=100;, score=-3258.066 total time=   0.2s
# [CV 3/5] END max_depth=7, max_features=log2, max_leaf_nodes=30, min_samples_leaf=4, min_weight_fraction_leaf=0.3, n_estimators=100;, score=-3104.809 total time=   0.2s
# [CV 4/5] END max_depth=7, max_features=log2, max_leaf_nodes=30, min_samples_leaf=4, min_weight_fraction_leaf=0.3, n_estimators=100;, score=-3455.014 total time=   0.1s
# [CV 5/5] END max_depth=7, max_features=log2, max_leaf_nodes=30, min_samples_leaf=4, min_weight_fraction_leaf=0.3, n_estimators=100;, score=-4991.432 total time=   0.2s
# [CV 1/5] END max_depth=7, max_features=log2, max_leaf_nodes=30, min_samples_leaf=4, min_weight_fraction_leaf=0.3, n_estimators=120;, score=-4310.624 total time=   0.2s
# [CV 2/5] END max_depth=7, max_features=log2, max_leaf_nodes=30, min_samples_leaf=4, min_weight_fraction_leaf=0.3, n_estimators=120;, score=-3189.172 total time=   0.2s
# [CV 3/5] END max_depth=7, max_features=log2, max_leaf_nodes=30, min_samples_leaf=4, min_weight_fraction_leaf=0.3, n_estimators=120;, score=-3138.630 total time=   0.3s
# [CV 4/5] END max_depth=7, max_features=log2, max_leaf_nodes=30, min_samples_leaf=4, min_weight_fraction_leaf=0.3, n_estimators=120;, score=-3483.307 total time=   0.3s
# [CV 5/5] END max_depth=7, max_features=log2, max_leaf_nodes=30, min_samples_leaf=4, min_weight_fraction_leaf=0.3, n_estimators=120;, score=-4939.220 total time=   0.3s
# [CV 1/5] END max_depth=7, max_features=log2, max_leaf_nodes=30, min_samples_leaf=4, min_weight_fraction_leaf=0.3, n_estimators=150;, score=-4300.731 total time=   0.4s
# [CV 2/5] END max_depth=7, max_features=log2, max_leaf_nodes=30, min_samples_leaf=4, min_weight_fraction_leaf=0.3, n_estimators=150;, score=-3342.510 total time=   0.4s
# [CV 3/5] END max_depth=7, max_features=log2, max_leaf_nodes=30, min_samples_leaf=4, min_weight_fraction_leaf=0.3, n_estimators=150;, score=-3130.104 total time=   0.4s
# [CV 4/5] END max_depth=7, max_features=log2, max_leaf_nodes=30, min_samples_leaf=4, min_weight_fraction_leaf=0.3, n_estimators=150;, score=-3510.466 total time=   0.4s
# [CV 5/5] END max_depth=7, max_features=log2, max_leaf_nodes=30, min_samples_leaf=4, min_weight_fraction_leaf=0.3, n_estimators=150;, score=-4975.612 total time=   0.4s
# [CV 1/5] END max_depth=7, max_features=log2, max_leaf_nodes=30, min_samples_leaf=4, min_weight_fraction_leaf=0.4, n_estimators=90;, score=-4435.126 total time=   0.2s
# [CV 2/5] END max_depth=7, max_features=log2, max_leaf_nodes=30, min_samples_leaf=4, min_weight_fraction_leaf=0.4, n_estimators=90;, score=-3178.618 total time=   0.2s
# [CV 3/5] END max_depth=7, max_features=log2, max_leaf_nodes=30, min_samples_leaf=4, min_weight_fraction_leaf=0.4, n_estimators=90;, score=-3273.726 total time=   0.2s
# [CV 4/5] END max_depth=7, max_features=log2, max_leaf_nodes=30, min_samples_leaf=4, min_weight_fraction_leaf=0.4, n_estimators=90;, score=-3654.412 total time=   0.2s
# [CV 5/5] END max_depth=7, max_features=log2, max_leaf_nodes=30, min_samples_leaf=4, min_weight_fraction_leaf=0.4, n_estimators=90;, score=-5228.698 total time=   0.2s
# [CV 1/5] END max_depth=7, max_features=log2, max_leaf_nodes=30, min_samples_leaf=4, min_weight_fraction_leaf=0.4, n_estimators=100;, score=-4376.303 total time=   0.2s
# [CV 2/5] END max_depth=7, max_features=log2, max_leaf_nodes=30, min_samples_leaf=4, min_weight_fraction_leaf=0.4, n_estimators=100;, score=-3202.099 total time=   0.2s
# [CV 3/5] END max_depth=7, max_features=log2, max_leaf_nodes=30, min_samples_leaf=4, min_weight_fraction_leaf=0.4, n_estimators=100;, score=-3260.578 total time=   0.2s
# [CV 4/5] END max_depth=7, max_features=log2, max_leaf_nodes=30, min_samples_leaf=4, min_weight_fraction_leaf=0.4, n_estimators=100;, score=-3762.170 total time=   0.2s
# [CV 5/5] END max_depth=7, max_features=log2, max_leaf_nodes=30, min_samples_leaf=4, min_weight_fraction_leaf=0.4, n_estimators=100;, score=-5227.766 total time=   0.2s
# [CV 1/5] END max_depth=7, max_features=log2, max_leaf_nodes=30, min_samples_leaf=4, min_weight_fraction_leaf=0.4, n_estimators=120;, score=-4432.425 total time=   0.2s
# [CV 2/5] END max_depth=7, max_features=log2, max_leaf_nodes=30, min_samples_leaf=4, min_weight_fraction_leaf=0.4, n_estimators=120;, score=-3067.646 total time=   0.2s
# [CV 3/5] END max_depth=7, max_features=log2, max_leaf_nodes=30, min_samples_leaf=4, min_weight_fraction_leaf=0.4, n_estimators=120;, score=-3242.006 total time=   0.2s
# [CV 4/5] END max_depth=7, max_features=log2, max_leaf_nodes=30, min_samples_leaf=4, min_weight_fraction_leaf=0.4, n_estimators=120;, score=-3591.670 total time=   0.2s
# [CV 5/5] END max_depth=7, max_features=log2, max_leaf_nodes=30, min_samples_leaf=4, min_weight_fraction_leaf=0.4, n_estimators=120;, score=-5185.391 total time=   0.2s
# [CV 1/5] END max_depth=7, max_features=log2, max_leaf_nodes=30, min_samples_leaf=4, min_weight_fraction_leaf=0.4, n_estimators=150;, score=-4392.269 total time=   0.2s
# [CV 2/5] END max_depth=7, max_features=log2, max_leaf_nodes=30, min_samples_leaf=4, min_weight_fraction_leaf=0.4, n_estimators=150;, score=-3246.575 total time=   0.2s
# [CV 3/5] END max_depth=7, max_features=log2, max_leaf_nodes=30, min_samples_leaf=4, min_weight_fraction_leaf=0.4, n_estimators=150;, score=-3273.115 total time=   0.2s
# [CV 4/5] END max_depth=7, max_features=log2, max_leaf_nodes=30, min_samples_leaf=4, min_weight_fraction_leaf=0.4, n_estimators=150;, score=-3667.827 total time=   0.3s
# [CV 5/5] END max_depth=7, max_features=log2, max_leaf_nodes=30, min_samples_leaf=4, min_weight_fraction_leaf=0.4, n_estimators=150;, score=-5340.794 total time=   0.2s
# GridSearchCV(cv=5, estimator=RandomForestRegressor(),
#              param_grid={'max_depth': [1, 3, 5, 7],
#                          'max_features': ['sqrt', 'log2'],
#                          'max_leaf_nodes': [None, 10, 20, 30],
#                          'min_samples_leaf': [1, 2, 3, 4],
#                          'min_weight_fraction_leaf': [0.1, 0.2, 0.3, 0.4],
#                          'n_estimators': [90, 100, 120, 150]},
#              scoring='neg_mean_squared_error', verbose=3)

# %%
tuned_model.best_params_
# Out:
# {'max_depth': 5,
#  'max_features': 'log2',
#  'max_leaf_nodes': 10,
#  'min_samples_leaf': 1,
#  'min_weight_fraction_leaf': 0.1,
#  'n_estimators': 90}

# %%
tuned_model.best_estimator_
# Out:
# RandomForestRegressor(max_depth=5, max_features='log2', max_leaf_nodes=10,
#                       min_weight_fraction_leaf=0.1, n_estimators=90)

# %%
tuned_hyper_model = RandomForestRegressor(max_depth=5, max_features='log2', max_leaf_nodes=10,min_weight_fraction_leaf=0.1, n_estimators=90)

# %%
tuned_hyper_model.fit(X_train,y_train)
# Out:
# RandomForestRegressor(max_depth=5, max_features='log2', max_leaf_nodes=10,
#                       min_weight_fraction_leaf=0.1, n_estimators=90)

# %%
tuned_pred = tuned_hyper_model.predict(X_test)

# %%
MAE = mean_absolute_error(y_test,tuned_pred)
MSE = mean_squared_error(y_test,tuned_pred)
RMSE = np.sqrt(MSE)
R2 = r2_score(y_test,tuned_pred)
print("Mean Absolute Error: ",MAE)
print("Mean Squared Error: ",MSE)
print("Root Mean Squared Error: ",RMSE)
print("R2 Score: ",R2)
# Out:
# Mean Absolute Error:  44.05545579813606
# Mean Squared Error:  3507.5852388035373
# Root Mean Squared Error:  59.2248701037287
# R2 Score:  0.5577582076525982

# %%
tuned_hyper_model.score(X_test,y_test)
# Out:
# 0.5577582076525982
