# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Ethans/Datasets/heart.csv')

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %% [markdown]
# **Dataset Description**
#
# The provided dataset contains information related to heart disease. Each row represents a patient, and the columns represent different features and target variables. Here is an explanation of each column:
#
# age: age in years
#
# sex: (1 = male; 0 = female)
#
# cp: chest pain type
#
# trestbps: resting blood pressure (in mm Hg on admission to the hospital)
#
# chol: serum cholestoral in mg/dl
#
# fbs: (fasting blood sugar > 120 mg/dl) (1 = true; 0 = false)
#
# restecg: resting electrocardiographic results
#
# thalach: maximum heart rate achieved
#
# exang: exercise induced angina (1 = yes; 0 = no)
#
# oldpeak: ST depression induced by exercise relative to rest
#
# slope: the slope of the peak exercise ST segment
#
# ca: number of major vessels (0-3) colored by flourosopy
#
# thal: 3 = normal; 6 = fixed defect; 7 = reversable defect
#
# target: refers to the presence of heart disease in the patient (1=yes, 0=no)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   int64
#  2   cp        1025 non-null   int64
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thalach   1025 non-null   int64
#  8   exang     1025 non-null   int64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  thal      1025 non-null   int64
#  13  target    1025 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 112.2 KB

# %%
# No of null/missing values
df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
df['target'].value_counts()
# Out:
# 1    526
# 0    499
# Name: target, dtype: int64

# %%
disease = len(df[df['target'] == 1])
no_disease = len(df[df['target'] == 0])

# %%
print("No of diseased: ",disease)
print("No of not diseased: ",no_disease)
# Out:
# No of diseased:  526
# No of not diseased:  499

# %%
# Categorical - qualitative and Continuos - quantitative columns
qualitative = []
quantitative = []
for feature in df.columns:
  if len(df[feature].unique()) <= 8:
    qualitative.append(feature)
  else:
    quantitative.append(feature)

# %%
qualitative
# Out:
# ['sex', 'cp', 'fbs', 'restecg', 'exang', 'slope', 'ca', 'thal', 'target']

# %%
quantitative
# Out:
# ['age', 'trestbps', 'chol', 'thalach', 'oldpeak']

# %%
df.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
df.loc[:,['age', 'trestbps', 'chol', 'thalach', 'oldpeak']] = scaler.fit_transform(df.loc[:,['age', 'trestbps', 'chol', 'thalach', 'oldpeak']])

# %%
df.head()
# Out:
#         age  sex  cp  trestbps      chol  fbs  restecg   thalach  exang  \
# 0 -0.268437    1   0 -0.377636 -0.659332    0        1  0.821321      0
# 1 -0.158157    1   0  0.479107 -0.833861    1        0  0.255968      1
# 2  1.716595    1   0  0.764688 -1.396233    0        1 -1.048692      1
# 3  0.724079    1   0  0.936037 -0.833861    0        1  0.516900      0
# 4  0.834359    0   0  0.364875  0.930822    1        1 -1.874977      0
#
#     oldpeak  slope  ca  thal  target
# 0 -0.060888      2   2     3       0
# 1  1.727137      0   0     3       0
# 2  1.301417      0   0     3       0
# 3 -0.912329      2   1     3       0
# 4  0.705408      1   3     2       0

# %%
X = df.drop('target',axis = 1)
y = df['target']

# %%
X.shape
# Out:
# (1025, 13)

# %%
y.shape
# Out:
# (1025,)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=101)
print('shape of X and y respectively (train) :', X_train.shape, y_train.shape)
print('shape of X and y respectively (test) :', X_test.shape, y_test.shape)
# Out:
# shape of X and y respectively (train) : (820, 13) (820,)
# shape of X and y respectively (test) : (205, 13) (205,)

# %%
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier(n_estimators = 4)

# %%
model.fit(X_train,y_train)
# Out:
# RandomForestClassifier(n_estimators=4)

# %%
y_pred = model.predict(X_test)

# %%
print("Training Score: ",model.score(X_train,y_train))
print("Testing Score: ",model.score(X_test,y_test))
# Out:
# Training Score:  0.9963414634146341
# Testing Score:  0.9804878048780488

# %%
from sklearn.metrics import accuracy_score

# %%
acc = accuracy_score(y_test,y_pred)
print("Accuracy Score: ",acc)
# Out:
# Accuracy Score:  0.9804878048780488

# %%
# Plot Confusion Matrix
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
cm = confusion_matrix(y_test, y_pred, labels=model.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm,display_labels=model.classes_)
disp.plot()

# %%
# Hyperparameter Tuning
from sklearn.model_selection import GridSearchCV

# %%
parameters = {"n_estimators":[90,100,120,140,150],
              "criterion":["gini","entropy"],
              "max_depth":[1,3,5,7,9],
              "min_samples_split":[2,3,4,6,7],
              "min_samples_leaf":[1,2,3,4,5],
              "max_features":["sqrt","log2",None]
}

# %%
tuned_model = GridSearchCV(model,param_grid = parameters,scoring = 'neg_mean_squared_error', cv = 5, verbose = 3)

# %%
X = df.drop('target',axis = 1)
y = df['target']

# %%
tuned_model.fit(X,y)
# Out:
# Streaming output truncated to the last 5000 lines.
# [CV 1/5] END criterion=entropy, max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=90;, score=-0.044 total time=   0.2s
# [CV 2/5] END criterion=entropy, max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=90;, score=-0.102 total time=   0.2s
# [CV 3/5] END criterion=entropy, max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=90;, score=-0.068 total time=   0.2s
# [CV 4/5] END criterion=entropy, max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=90;, score=-0.088 total time=   0.2s
# [CV 5/5] END criterion=entropy, max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=90;, score=-0.112 total time=   0.2s
# [CV 1/5] END criterion=entropy, max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=-0.034 total time=   0.2s
# [CV 2/5] END criterion=entropy, max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=-0.093 total time=   0.2s
# [CV 3/5] END criterion=entropy, max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=-0.059 total time=   0.2s
# [CV 4/5] END criterion=entropy, max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=-0.073 total time=   0.3s
# [CV 5/5] END criterion=entropy, max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=-0.112 total time=   0.3s
# [CV 1/5] END criterion=entropy, max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=120;, score=-0.039 total time=   0.4s
# [CV 2/5] END criterion=entropy, max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=120;, score=-0.093 total time=   0.4s
# [CV 3/5] END criterion=entropy, max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=120;, score=-0
total time=   0.3s
# [CV 1/5] END criterion=entropy, max_depth=5, max_features=log2, min_samples_leaf=3, min_samples_split=3, n_estimators=90;, score=-0.039 total time=   0.2s
# [CV 2/5] END criterion=entropy, max_depth=5, max_features=log2, min_samples_leaf=3, min_samples_split=3, n_estimators=90;, score=-0.112 total time=   0.2s
# [CV 3/5] END criterion=entropy, max_depth=5, max_features=log2, min_samples_leaf=3, min_samples_split=3, n_estimators=90;, score=-0.054 total time=   0.2s
# [CV 4/5] END criterion=entropy, max_depth=5, max_features=log2, min_samples_leaf=3, min_samples_split=3, n_estimators=90;, score=-0.102 total time=   0.2s
# [CV 5/5] END criterion=entropy, max_depth=5, max_features=log2, min_samples_leaf=3, min_samples_split=3, n_estimators=90;, score=-0.132 total time=   0.2s
# [CV 1/5] END criterion=entropy, max_depth=5, max_features=log2, min_samples_leaf=3, min_samples_split=3, n_estimators=100;, score=-0.054 total time=   0.2s
# [CV 2/5] END criterion=entropy, max_depth=5, max_features=log2, min_samples_leaf=3, min_samples_split=3, n_estimators=100;, score=-0.102 total time=   0.2s
# [CV 3/5] END criterion=entropy, max_depth=5, max_features=log2, min_samples_leaf=3, min_samples_split=3, n_estimators=100;, score=-0.068 total time=   0.2s
# [CV 4/5] END criterion=entropy, max_depth=5, max_features=log2, min_samples_leaf=3, min_samples_split=3, n_estimators=100;, score=-0.093 total time=   0.2s
# [CV 5/5] END criterion=entropy, max_depth=5, max_features=log2, min_samples_leaf=3, min_samples_split=3, n_estimators=100;, score=-0.122 total time=   0.2s
# [CV 1/5] END criterion=entropy, max_depth=5, max_features=log2, min_samples_leaf=3, min_samples_split=3, n_estimators=120;, score=-0.039 total time=   0.3s
# [CV 2/5] END criterion=entropy, max_depth=5, max_features=log2, min_samples_leaf=3, min_samples_split=3, n_estimators=120;, score=-0.098 total time=   0.3s
# [CV 3/5] END criterion=entropy, max_depth=5, max_features=log2, min_samples_leaf=3, min_samples_split=3, n_estimators=120;, score=-0.063 total time=   0.3s
# [CV 4/5] END criterion=entropy, max_depth=5, max_features=log2, min_samples_leaf=3, min_samples_split=3, n_estimators=120;, score=-0.107 total time=   0.3s
# [CV 5/5] END criterion=entropy, max_depth=5, max_features=log2, min_samples_leaf=3, min_samples_split=3, n_estimators=120;, score=-0.137 total time=   0.3s
# [CV 1/5] END criterion=entropy, max_depth=5, max_features=log2, min_samples_leaf=3, min_samples_split=3, n_estimators=140;, score=-0.044 total time=   0.3s
# [CV 2/5] END criterion=entropy, max_depth=5, max_features=log2, min_samples_leaf=3, min_samples_split=3, n_estimators=140;, score=-0.093 total time=   0.3s
# [CV 3/5] END criterion=entropy, max_depth=5, max_features=log2, min_samples_leaf=3, min_samples_split=3, n_estimators=140;, score=-0.073 total time=   0.3s
# [CV 4/5] END criterion=entropy, max_depth=5, max_features=log2, min_samples_leaf=3, min_samples_split=3, n_estimators=140;, score=-0.102 total time=   0.3s
# [CV 5/5] END criterion=entropy, max_depth=5, max_features=log2, min_samples_leaf=3, min_samples_split=3, n_estimators=140;, score=-0.112 total time=   0.3s
# [CV 1/5] END criterion=entropy, max_depth=5, max_features=log2, min_samples_leaf=3, min_samples_split=3, n_estimators=150;, score=-0.034 total time=   0.3s
# [CV 2/5] END criterion=entropy, max_depth=5, max_features=log2, min_samples_leaf=3, min_samples_split=3, n_estimators=150;, score=-0.117 total time=   0.3s
# [CV 3/5] END criterion=entropy, max_depth=5, max_features=log2, min_samples_leaf=3, min_samples_split=3, n_estimators=150;, score=-0.063 total time=   0.3s
# [CV 4/5] END criterion=entropy, max_depth=5, max_features=log2, min_samples_leaf=3, min_samples_split=3, n_estimators=150;, score=-0.112 total time=   0.3s
# [CV 5/5] END criterion=entropy, max_depth=5, max_features=log2, min_samples_leaf=3, min_samples_split=3, n_estimators=150;, score=-0.122 total time=   0.3s
# [CV 1/5] END criterion=entropy, max_depth=5, max_features=log2, min_samples_leaf=3, min_samples_split=4, n_estimators=90;, score=-0.049 total time=   0.2s
# [CV 2/5] END criterion=entropy, max_depth=5, max_features=log2, min_samples_leaf=3, min_samples_split=4, n_estimators=90;, score=-0.112 total time=   0.2s
# [CV 3/5] END criterion=entropy, max_depth=5, max_features=log2, min_samples_leaf=3, min_samples_split=4, n_estimators=90;, score=-0.059 total time=   0.2s
# [CV 4/5] END criterion=entropy, max_depth=5, max_features=log2, min_samples_leaf=3, min_samples_split=4, n_estimators=90;, score=-0.098 total time=   0.2s
# [CV 5/5] END criterion=entropy, max_depth=5, max_features=log2, min_samples_leaf=3, min_samples_split=4, n_estimators=90;, score=-0.137 total time=   0.2s
# [CV 1/5] END criterion=entropy, max_depth=5, max_features=log2, min_samples_leaf=3, min_samples_split=4, n_estimators=100;, score=-0.039 total time=   0.2s
# [CV 2/5] END criterion=entropy, max_depth=5, max_features=log2, min_samples_leaf=3, min_samples_split=4, n_estimators=100;, score=-0.102 total time=   0.2s
# ...
# [CV 2/5] END criterion=entropy, max_depth=9, max_features=None, min_samples_leaf=5, min_samples_split=3, n_estimators=90;, score=-0.049 total time=   0.4s
# [CV 3/5] END criterion=entropy, max_depth=9, max_features=None, min_samples_leaf=5, min_samples_split=3, n_estimators=90;, score=-0.034 total time=   0.4s
# [CV 4/5] END criterion=entropy, max_depth=9, max_features=None, min_samples_leaf=5, min_samples_split=3, n_estimators=90;, score=-0.029 total time=   0.3s
# [CV 5/5] END criterion=entropy, max_depth=9, max_features=None, min_samples_leaf=5, min_samples_split=3, n_estimators=90;, score=-0.044 total time=   0.3s
# [CV 1/5] END criterion=entropy, max_depth=9, max_features=None, min_samples_leaf=5, min_samples_split=3, n_estimators=100;, score=-0.010 total time=   0.3s
# [CV 2/5] END criterion=entropy, max_depth=9, max_features=None, min_samples_leaf=5, min_samples_split=3, n_estimators=100;, score=-0.054 total time=   0.3s
# [CV 3/5] END criterion=entropy, max_depth=9, max_features=None, min_samples_leaf=5, min_samples_split=3, n_estimators=100;, score=-0.029 total time=   0.3s
# [CV 4/5] END criterion=entropy, max_depth=9, max_features=None, min_samples_leaf=5, min_samples_split=3, n_estimators=100;, score=-0.034 total time=   0.3s
# [CV 5/5] END criterion=entropy, max_depth=9, max_features=None, min_samples_leaf=5, min_samples_split=3, n_estimators=100;, score=-0.054 total time=   0.3s
# [CV 1/5] END criterion=entropy, max_depth=9, max_features=None, min_samples_leaf=5, min_samples_split=3, n_estimators=120;, score=-0.010 total time=   0.4s
# [CV 2/5] END criterion=entropy, max_depth=9, max_features=None, min_samples_leaf=5, min_samples_split=3, n_estimators=120;, score=-0.054 total time=   0.4s
# [CV 3/5] END criterion=entropy, max_depth=9, max_features=None, min_samples_leaf=5, min_samples_split=3, n_estimators=120;, score=-0.039 total time=   0.4s
# [CV 4/5] END criterion=entropy, max_depth=9, max_features=None, min_samples_leaf=5, min_samples_split=3, n_estimators=120;, score=-0.024 total time=   0.4s
# [CV 5/5] END criterion=entropy, max_depth=9, max_features=None, min_samples_leaf=5, min_samples_split=3, n_estimators=120;, score=-0.078 total time=   0.4s
# [CV 1/5] END criterion=entropy, max_depth=9, max_features=None, min_samples_leaf=5, min_samples_split=3, n_estimators=140;, score=-0.024 total time=   0.4s
# [CV 2/5] END criterion=entropy, max_depth=9, max_features=None, min_samples_leaf=5, min_samples_split=3, n_estimators=140;, score=-0.054 total time=   0.4s
# [CV 3/5] END criterion=entropy, max_depth=9, max_features=None, min_samples_leaf=5, min_samples_split=3, n_estimators=140;, score=-0.039 total time=   0.4s
# [CV 4/5] END criterion=entropy, max_depth=9, max_features=None, min_samples_leaf=5, min_samples_split=3, n_estimators=140;, score=-0.034 total time=   0.4s
# [CV 5/5] END criterion=entropy, max_depth=9, max_features=None, min_samples_leaf=5, min_samples_split=3, n_estimators=140;, score=-0.049 total time=   0.4s
# [CV 1/5] END criterion=entropy, max_depth=9, max_features=None, min_samples_leaf=5, min_samples_split=3, n_estimators=150;, score=-0.020 total time=   0.4s
# [CV 2/5] END criterion=entropy, max_depth=9, max_features=None, min_samples_leaf=5, min_samples_split=3, n_estimators=150;, score=-0.054 total time=   0.4s
# [CV 3/5] END criterion=entropy, max_depth=9, max_features=None, min_samples_leaf=5, min_samples_split=3, n_estimators=150;, score=-0.024 total time=   0.4s
# [CV 4/5] END criterion=entropy, max_depth=9, max_features=None, min_samples_leaf=5, min_samples_split=3, n_estimators=150;, score=-0.029 total time=   0.4s
# [CV 5/5] END criterion=entropy, max_depth=9, max_features=None, min_samples_leaf=5, min_samples_split=3, n_estimators=150;, score=-0.054 total time=   0.4s
# [CV 1/5] END criterion=entropy, max_depth=9, max_features=None, min_samples_leaf=5, min_samples_split=4, n_estimators=90;, score=-0.010 total time=   0.3s
# [CV 2/5] END criterion=entropy, max_depth=9, max_features=None, min_samples_leaf=5, min_samples_split=4, n_estimators=90;, score=-0.054 total time=   0.3s
# [CV 3/5] END criterion=entropy, max_depth=9, max_features=None, min_samples_leaf=5, min_samples_split=4, n_estimators=90;, score=-0.024 total time=   0.3s
# [CV 4/5] END criterion=entropy, max_depth=9, max_features=None, min_samples_leaf=5, min_samples_split=4, n_estimators=90;, score=-0.029 total time=   0.3s
# [CV 5/5] END criterion=entropy, max_depth=9, max_features=None, min_samples_leaf=5, min_samples_split=4, n_estimators=90;, score=-0.068 total time=   0.3s
# [CV 1/5] END criterion=entropy, max_depth=9, max_features=None, min_samples_leaf=5, min_samples_split=4, n_estimators=100;, score=-0.020 total time=   0.3s
# [CV 2/5] END criterion=entropy, max_depth=9, max_features=None, min_samples_leaf=5, min_samples_split=4, n_estimators=100;, score=-0.054 total time=   0.3s
# [CV 3/5] END criterion=entropy, max_depth=9, max_features=None, min_samples_leaf=5, min_samples_split=4, n_estimators=100;, score=-0.029 total time=   0.5s
# [CV 4/5] END criterion=entropy, max_depth=9, max_features=None, min_samples_leaf=5, min_samples_split=4, n_estimators=100;, score=-0.034 total time=   0.5s
# [CV 5/5] END criterion=entropy, max_depth=9, max_features=None, min_samples_leaf=5, min_samples_split=4, n_estimators=100;, score=-0.063 total time=   0.5s
# [CV 1/5] END criterion=entropy, max_depth=9, max_features=None, min_samples_leaf=5, min_samples_split=4, n_estimators=120;, score=-0.034 total time=   0.6s
# [CV 2/5] END criterion=entropy, max_depth=9, max_features=None, min_samples_leaf=5, min_samples_split=4, n_estimators=120;, score=-0.049 total time=   0.5s
# [CV 3/5] END criterion=entropy, max_depth=9, max_features=None, min_samples_leaf=5, min_samples_split=4, n_estimators=120;, score=-0.029 total time=   0.5s
# [CV 4/5] END criterion=entropy, max_depth=9, max_features=None, min_samples_leaf=5, min_samples_split=4, n_estimators=120;, score=-0.024 total time=   0.6s
# [CV 5/5] END criterion=entropy, max_depth=9, max_features=None, min_samples_leaf=5, min_samples_split=4, n_estimators=120;, score=-0.083 total time=   0.6s
# [CV 1/5] END criterion=entropy, max_depth=9, max_features=None, min_samples_leaf=5, min_samples_split=4, n_estimators=140;, score=-0.005 total time=   0.4s
# [CV 2/5] END criterion=entropy, max_depth=9, max_features=None, min_samples_leaf=5, min_samples_split=4, n_estimators=140;, score=-0.054 total time=   0.4s
# [CV 3/5] END criterion=entropy, max_depth=9, max_features=None, min_samples_leaf=5, min_samples_split=4, n_estimators=140;, score=-0.029 total time=   0.4s
# [CV 4/5] END criterion=entropy, max_depth=9, max_features=None, min_samples_leaf=5, min_samples_split=4, n_estimators=140;, score=-0.029 total time=   0.4s
# [CV 5/5] END criterion=entropy, max_depth=9, max_features=None, min_samples_leaf=5, min_samples_split=4, n_estimators=140;, score=-0.059 total time=   0.4s
# [CV 1/5] END criterion=entropy, max_depth=9, max_features=None, min_samples_leaf=5, min_samples_split=4, n_estimators=150;, score=-0.010 total time=   0.4s
# [CV 2/5] END criterion=entropy, max_depth=9, max_features=None, min_samples_leaf=5, min_samples_split=4, n_estimators=150;, score=-0.054 total time=   0.4s
# [CV 3/5] END criterion=entropy, max_depth=9, max_features=None, min_samples_leaf=5, min_samples_split=4, n_estimators=150;, score=-0.029 total time=   0.5s
# [CV 4/5] END criterion=entropy, max_depth=9, max_features=None, min_samples_leaf=5, min_samples_split=4, n_estimators=150;, score=-0.029 total time=   0.4s
# [CV 5/5] END criterion=entropy, max_depth=9, max_features=None, min_samples_leaf=5, min_samples_split=4, n_estimators=150;, score=-0.068 total time=   0.5s
# [CV 1/5] END criterion=entropy, max_depth=9, max_features=None, min_samples_leaf=5, min_samples_split=6, n_estimators=90;, score=-0.015 total time=   0.3s
# [CV 2/5] END criterion=entropy, max_depth=9, max_features=None, min_samples_leaf=5, min_samples_split=6, n_estimators=90;, score=-0.049 total time=   0.3s
# [CV 3/5] END criterion=entropy, max_depth=9, max_features=None, min_samples_leaf=5, min_samples_split=6, n_estimators=90;, score=-0.034 total time=   0.3s
# [CV 4/5] END criterion=entropy, max_depth=9, max_features=None, min_samples_leaf=5, min_samples_split=6, n_estimators=90;, score=-0.034 total time=   0.3s
# [CV 5/5] END criterion=entropy, max_depth=9, max_features=None, min_samples_leaf=5, min_samples_split=6, n_estimators=90;, score=-0.063 total time=   0.3s
# [CV 1/5] END criterion=entropy, max_depth=9, max_features=None, min_samples_leaf=5, min_samples_split=6, n_estimators=100;, score=-0.024 total time=   0.3s
# [CV 2/5] END criterion=entropy, max_depth=9, max_features=None, min_samples_leaf=5, min_samples_split=6, n_estimators=100;, score=-0.054 total time=   0.3s
# [CV 3/5] END criterion=entropy, max_depth=9, max_features=None, min_samples_leaf=5, min_samples_split=6, n_estimators=100;, score=-0.024 total time=   0.3s
# [CV 4/5] END criterion=entropy, max_depth=9, max_features=None, min_samples_leaf=5, min_samples_split=6, n_estimators=100;, score=-0.029 total time=   0.3s
# [CV 5/5] END criterion=entropy, max_depth=9, max_features=None, min_samples_leaf=5, min_samples_split=6, n_estimators=100;, score=-0.068 total time=   0.3s
# [CV 1/5] END criterion=entropy, max_depth=9, max_features=None, min_samples_leaf=5, min_samples_split=6, n_estimators=120;, score=-0.015 total time=   0.4s
# [CV 2/5] END criterion=entropy, max_depth=9, max_features=None, min_samples_leaf=5, min_samples_split=6, n_estimators=120;, score=-0.054 total time=   0.4s
# [CV 3/5] END criterion=entropy, max_depth=9, max_features=None, min_samples_leaf=5, min_samples_split=6, n_estimators=120;, score=-0.039 total time=   0.4s
# [CV 4/5] END criterion=entropy, max_depth=9, max_features=None, min_samples_leaf=5, min_samples_split=6, n_estimators=120;, score=-0.029 total time=   0.4s
# [CV 5/5] END criterion=entropy, max_depth=9, max_features=None, min_samples_leaf=5, min_samples_split=6, n_estimators=120;, score=-0.078 total time=   0.4s
# [CV 1/5] END criterion=entropy, max_depth=9, max_features=None, min_samples_leaf=5, min_samples_split=6, n_estimators=140;, score=-0.015 total time=   0.4s
# [CV 2/5] END criterion=entropy, max_depth=9, max_features=None, min_samples_leaf=5, min_samples_split=6, n_estimators=140;, score=-0.054 total time=   0.4s
# [CV 3/5] END criterion=entropy, max_depth=9, max_features=None, min_samples_leaf=5, min_samples_split=6, n_estimators=140;, score=-0.029 total time=   0.6s
# [CV 4/5] END criterion=entropy, max_depth=9, max_features=None, min_samples_leaf=5, min_samples_split=6, n_estimators=140;, score=-0.029 total time=   0.6s
# [CV 5/5] END criterion=entropy, max_depth=9, max_features=None, min_samples_leaf=5, min_samples_split=6, n_estimators=140;, score=-0.063 total time=   0.6s
# [CV 1/5] END criterion=entropy, max_depth=9, max_features=None, min_samples_leaf=5, min_samples_split=6, n_estimators=150;, score=-0.020 total time=   0.7s
# [CV 2/5] END criterion=entropy, max_depth=9, max_features=None, min_samples_leaf=5, min_samples_split=6, n_estimators=150;, score=-0.044 total time=   0.7s
# [CV 3/5] END criterion=entropy, max_depth=9, max_features=None, min_samples_leaf=5, min_samples_split=6, n_estimators=150;, score=-0.029 total time=   0.7s
# [CV 4/5] END criterion=entropy, max_depth=9, max_features=None, min_samples_leaf=5, min_samples_split=6, n_estimators=150;, score=-0.034 total time=   0.7s
# [CV 5/5] END criterion=entropy, max_depth=9, max_features=None, min_samples_leaf=5, min_samples_split=6, n_estimators=150;, score=-0.063 total time=   0.5s
# [CV 1/5] END criterion=entropy, max_depth=9, max_features=None, min_samples_leaf=5, min_samples_split=7, n_estimators=90;, score=-0.005 total time=   0.3s
# [CV 2/5] END criterion=entropy, max_depth=9, max_features=None, min_samples_leaf=5, min_samples_split=7, n_estimators=90;, score=-0.054 total time=   0.3s
# [CV 3/5] END criterion=entropy, max_depth=9, max_features=None, min_samples_leaf=5, min_samples_split=7, n_estimators=90;, score=-0.024 total time=   0.3s
# [CV 4/5] END criterion=entropy, max_depth=9, max_features=None, min_samples_leaf=5, min_samples_split=7, n_estimators=90;, score=-0.029 total time=   0.3s
# [CV 5/5] END criterion=entropy, max_depth=9, max_features=None, min_samples_leaf=5, min_samples_split=7, n_estimators=90;, score=-0.063 total time=   0.3s
# [CV 1/5] END criterion=entropy, max_depth=9, max_features=None, min_samples_leaf=5, min_samples_split=7, n_estimators=100;, score=-0.015 total time=   0.3s
# [CV 2/5] END criterion=entropy, max_depth=9, max_features=None, min_samples_leaf=5, min_samples_split=7, n_estimators=100;, score=-0.054 total time=   0.3s
# [CV 3/5] END criterion=entropy, max_depth=9, max_features=None, min_samples_leaf=5, min_samples_split=7, n_estimators=100;, score=-0.039 total time=   0.3s
# [CV 4/5] END criterion=entropy, max_depth=9, max_features=None, min_samples_leaf=5, min_samples_split=7, n_estimators=100;, score=-0.024 total time=   0.3s
# [CV 5/5] END criterion=entropy, max_depth=9, max_features=None, min_samples_leaf=5, min_samples_split=7, n_estimators=100;, score=-0.068 total time=   0.3s
# [CV 1/5] END criterion=entropy, max_depth=9, max_features=None, min_samples_leaf=5, min_samples_split=7, n_estimators=120;, score=-0.015 total time=   0.4s
# [CV 2/5] END criterion=entropy, max_depth=9, max_features=None, min_samples_leaf=5, min_samples_split=7, n_estimators=120;, score=-0.054 total time=   0.4s
# [CV 3/5] END criterion=entropy, max_depth=9, max_features=None, min_samples_leaf=5, min_samples_split=7, n_estimators=120;, score=-0.024 total time=   0.4s
# [CV 4/5] END criterion=entropy, max_depth=9, max_features=None, min_samples_leaf=5, min_samples_split=7, n_estimators=120;, score=-0.029 total time=   0.4s
# [CV 5/5] END criterion=entropy, max_depth=9, max_features=None, min_samples_leaf=5, min_samples_split=7, n_estimators=120;, score=-0.054 total time=   0.4s
# [CV 1/5] END criterion=entropy, max_depth=9, max_features=None, min_samples_leaf=5, min_samples_split=7, n_estimators=140;, score=-0.020 total time=   0.4s
# [CV 2/5] END criterion=entropy, max_depth=9, max_features=None, min_samples_leaf=5, min_samples_split=7, n_estimators=140;, score=-0.054 total time=   0.4s
# [CV 3/5] END criterion=entropy, max_depth=9, max_features=None, min_samples_leaf=5, min_samples_split=7, n_estimators=140;, score=-0.029 total time=   0.4s
# [CV 4/5] END criterion=entropy, max_depth=9, max_features=None, min_samples_leaf=5, min_samples_split=7, n_estimators=140;, score=-0.029 total time=   0.4s
# [CV 5/5] END criterion=entropy, max_depth=9, max_features=None, min_samples_leaf=5, min_samples_split=7, n_estimators=140;, score=-0.073 total time=   0.4s
# [CV 1/5] END criterion=entropy, max_depth=9, max_features=None, min_samples_leaf=5, min_samples_split=7, n_estimators=150;, score=-0.024 total time=   0.4s
# [CV 2/5] END criterion=entropy, max_depth=9, max_features=None, min_samples_leaf=5, min_samples_split=7, n_estimators=150;, score=-0.044 total time=   0.5s
# [CV 3/5] END criterion=entropy, max_depth=9, max_features=None, min_samples_leaf=5, min_samples_split=7, n_estimators=150;, score=-0.029 total time=   0.5s
# [CV 4/5] END criterion=entropy, max_depth=9, max_features=None, min_samples_leaf=5, min_samples_split=7, n_estimators=150;, score=-0.029 total time=   0.5s
# [CV 5/5] END criterion=entropy, max_depth=9, max_features=None, min_samples_leaf=5, min_samples_split=7, n_estimators=150;, score=-0.078 total time=   0.5s
# GridSearchCV(cv=5, estimator=RandomForestClassifier(n_estimators=4),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [1, 3, 5, 7, 9],
#                          'max_features': ['sqrt', 'log2', None],
#                          'min_samples_leaf': [1, 2, 3, 4, 5],
#                          'min_samples_split': [2, 3, 4, 6, 7],
#                          'n_estimators': [90, 100, 120, 140, 150]},
#              scoring='neg_mean_squared_error', verbose=3)

# %%
tuned_model.best_estimator_
# Out:
# RandomForestClassifier(criterion='entropy', max_depth=9, max_features=None,
#                        n_estimators=120)

# %%
tuned_hyper_model = RandomForestClassifier(criterion='entropy', max_depth=9, max_features=None,n_estimators=120)

# %%
tuned_hyper_model.fit(X_train,y_train)
# Out:
# RandomForestClassifier(criterion='entropy', max_depth=9, max_features=None,
#                        n_estimators=120)

# %%
tuned_pred = tuned_hyper_model.predict(X_test)

# %%
print("Training Score: ",tuned_hyper_model.score(X_train,y_train))
print("Testing Score: ",tuned_hyper_model.score(X_test,y_test))
# Out:
# Training Score:  1.0
# Testing Score:  1.0

# %%
# Plot Confusion Matrix
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
cm = confusion_matrix(y_test, tuned_pred, labels=tuned_hyper_model.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm,display_labels=tuned_hyper_model.classes_)
disp.plot()

# %%
acc = accuracy_score(y_test,tuned_pred)
print("Accuracy Score: ",acc)
# Out:
# Accuracy Score:  1.0
